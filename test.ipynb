# %%
import  hashlib 
from time import time
import json

# %%
class data:
    def __init__(self , hospital = None , model_id = None , model_weight = None):
        self.hospital = hospital
        self.model_id = model_id
        self.model_weight = dict(model_weight)
        self.avg_weight = dict()
        
    def get_fed(self):
        temp = 0
        dict_key = list(self.model_weight.keys()) 
        print(self.model_weight)   
        for element in dict_key:
            name = element
            element = self.model_weight[element]
            try:
                self.avg_weight[name] = []
                for i in range (0,len(element[0])):
                    for micro_element in element:
                        temp+=micro_element[i]
                    temp=temp/len(element)
                    self.avg_weight[name].append(temp)
                    temp = 0
            except:
                    temp = 0
                    for micro_element in element:
                        temp+=micro_element
                    temp = temp/len(element)
                    self.avg_weight[name] = temp
                    temp  = 0 
        return self.avg_weight

# %%
block  = {'index': 9, 'timestamp': 1762411716.7384691, 'data': ([[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]], [[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]]), 'previous_hash': '0000d6221f929c3845a5861a74287def54c1ce9bf1c049c02a6bda9098c289ab', 'nonce': 43188, 'hash': '000095bd92add4d759b55699d7147e35949d75e41a256ab8bced99b034555801'}

# %%
block  = {'index': 9, 'timestamp': 1762411716.7384691, 'data': ([[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]], [[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]]), 'previous_hash': '0000d6221f929c3845a5861a74287def54c1ce9bf1c049c02a6bda9098c289ab', 'nonce': 43188, 'hash': '000095bd92add4d759b55699d7147e35949d75e41a256ab8bced99b034555801'}

# %%
dat = data(hospital=1,model_id=7,model_weight={'model_weight':[[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756], [-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]],'model_bais':[1,2,3,4,5]})

# %%
dat.get_fed()
# Out:
# {'model_weight': [[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756], [-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.
# ...

# %%
dat = dat.__dict__

# %%
dat
# Out:
# {'hospital': 1,
#  'model_id': 7,
#  'model_weight': {'model_weight': [[-0.016499387004132962,
#     0.5113355397529356,
#     0.6335357070484462,
#     0.49596018079829013,
#     0.526688811835621,
#     0.12100522284897332,
#     -0.05767082298718232,
#     0.5088059039025762,
#     0.6666721944626021,
#     0.06701400009099372,
#     -0.24485339547731386,
#     0.6736992318817053,
#     -0.047531397293650184,
#     0.4633442685726828,
#     0.5277767702185666,
#     0.017517292063693773,
#     -0.40221750844864834,
#     -0.024264224590846,
#     0.006929606087198716,
#     -0.11605001894422662,
#     -0.5316425482685049,
#     0.7620486201482993,
#     0.8237971895029202,
#     0.6755413144170347,
#     0.705098220862384,
#     0.5019692377144085,
#     0.2689324871375744,
#     0.584039260191407,
#     0.6822837955300677,
#     0.6115207772340904,
#     0.22293981919547756],
#    [-0.016499387004132962,
#     0.5113355397529356,
#     0.6335357070484462,
# ...

# %%
class Blockchain:
    def __init__(self, difficulty=1):
        self.chain = []
        self.difficulty = difficulty
        genesis_block = self.create_block("This is the genesis block", "0")
        self.chain.append(genesis_block)

    def create_block(self, data, previous_hash):
        block = {
            'index': len(self.chain) + 1,
            'timestamp': time(),
            'data': data,
            'previous_hash': previous_hash,
            'nonce': 0,
            'hash': None
        }
        block['hash'] = self.mine_block(block)
        return block
    

    def compute_hash(self, block):
        block_copy = block.copy()
        block_copy['hash'] = None
        block_string = json.dumps(block_copy, sort_keys=True).encode()
        return hashlib.sha256(block_string).hexdigest()

    def mine_block(self, block):
        while True:
            hash_value = self.compute_hash(block)
            if hash_value.startswith('0' * self.difficulty):
                return hash_value
            else:
                block['nonce'] += 1

    def add_block(self, data):
        previous_hash = self.chain[-1]['hash']
        new_block = self.create_block(data, previous_hash)
        self.chain.append(new_block)

    def print_chain(self):
        print("\n Blockchain ")
        for block in self.chain:
            print(f"\nBlock {block['index']}")
            print(f"Timestamp: {block['timestamp']}")
            print(f"Data: {block['data']}")
            print(f"Previous Hash: {block['previous_hash']}")
            print(f"Nonce: {block['nonce']}")
            print(f"Hash: {block['hash']}")

    def get_last_block(self):
        return self.chain[-1]

# %%
list_of_trans = []

# %%
(-0.016499387004132962-0.016499387004132962)/2
# Out:
# -0.016499387004132962

# %%
with open("test.txt",'r') as f:
    temp = f.read()
    list_of_trans = temp.splitlines()

# %%
blockchain = Blockchain(difficulty=1)
for element in list_of_trans:
    blockchain.add_block(element)
    blockchain.print_chain()
# Out:
#  Blockchain
#
# Block 1
# Timestamp: 1762424613.121996
# Data: This is the genesis block
# Previous Hash: 0
# Nonce: 16
# Hash: 00cb7bba09193e889fc2034e0ee5df390b3fda482b185bad28d0a23cbae2d5e4
#
# Block 2
# Timestamp: 1762424613.122796
# Data: hospital A has provided model weight w1 41
# Previous Hash: 00cb7bba09193e889fc2034e0ee5df390b3fda482b185bad28d0a23cbae2d5e4
# Nonce: 21
# Hash: 09ada5cd3987267772719c7117be0c3573bdda12b9e11cdc00d492c758334231
#
#  Blockchain
#
# Block 1
# Timestamp: 1762424613.121996
# Data: This is the genesis block
# Previous Hash: 0
# Nonce: 16
# Hash: 00cb7bba09193e889fc2034e0ee5df390b3fda482b185bad28d0a23cbae2d5e4
#
# Block 2
# Timestamp: 1762424613.122796
# Data: hospital A has provided model weight w1 41
# Previous Hash: 00cb7bba09193e889fc2034e0ee5df390b3fda482b185bad28d0a23cbae2d5e4
# Nonce: 21
# Hash: 09ada5cd3987267772719c7117be0c3573bdda12b9e11cdc00d492c758334231
#
# Block 3
# Timestamp: 1762424613.123004
# ...

# %%
a = blockchain.get_last_block()

# %%
print(a)
# Out:
# {'index': 58, 'timestamp': 1762424613.337163, 'data': 'hospital y has provided model weight w1 47', 'previous_hash': '0f1cc7f1fda8af6ba51196a70939a022be3ad602d680d0f681d795a50328a50c', 'nonce': 13, 'hash': '0f88c2a12a45c30616654145472ed5ca89fc5a894632134de15960ad8a51960f'}

# %%
block_string = json.dumps('Hello', sort_keys=True).encode()
hashlib.sha256(block_string).hexdigest()
# Out:
# 'c25bf945aaff8fe16826d3c1ef117044d6cc1af8e0e9f0b4162308460a8207a7'
