# %%
diction = {
    'a' : [[1,2,3],[4,5,6],[7,8,9]],
    'b' : [1,2,3,4,5,7,8,9,10],
    'c':[1,2,3,4]
}

# %%
data =  [[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]], [[-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756]]
temp_list = f'{data}'
temp_list = temp_list.replace('[[','[')
temp_list = temp_list.replace(']]',']')
temp_list
# Out:
# '([-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756], [-0.016499387004132962, 0.5113355397529356, 0.6335357070484462, 0.49596018079829013, 0.526688811835621, 0.12100522284897332, -0.05767082298718232, 0.5088059039025762, 0.6666721944626021, 0.06701400009099372, -0.24485339547731386, 0.6736992318817053, -0.047531397293650184, 0.4633442685726828, 0.5277767702185666, 0.017517292063693773, -0.40221750844864834, -0.024264224590846, 0.006929606087198716, -0.11605001894422662, -0.5316425482685049, 0.7620486201482993, 0.8237971895029202, 0.6755413144170347, 0.705098220862384, 0.5019692377144085, 0.2689324871375744, 0.584039260191407, 0.6822837955300677, 0.6115207772340904, 0.22293981919547756])'

# %%
def data_preprocessing(data):
# Out:
#   Cell In[158], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
dict_key = list(diction.keys())

# %%
fed_avg = {}

# %%
temp = 0
for element in dict_key:
    name = element
    element = diction[element]
    try:
        fed_avg[name] = []
        for i in range (0,len(element[0])):
            for micro_element in element:
                print(micro_element)
                temp+=micro_element[i]
                print(temp)
            temp=temp/len(element)
            fed_avg[name].append(temp)
            print(temp)
            temp = 0
    except:
            temp = 0
            for micro_element in element:
                 temp+=micro_element
            temp = temp/len(element)
            print(temp)
            fed_avg[name] = temp
            temp  = 0
# Out:
# [1, 2, 3]
# 1
# [4, 5, 6]
# 5
# [7, 8, 9]
# 12
# 4.0
# [1, 2, 3]
# 2
# [4, 5, 6]
# 7
# [7, 8, 9]
# 15
# 5.0
# [1, 2, 3]
# 3
# [4, 5, 6]
# 9
# [7, 8, 9]
# 18
# 6.0
# 5.444444444444445
# 2.5

# %%
fed_avg
# Out:
# {'a': [4.0, 5.0, 6.0], 'b': 5.444444444444445, 'c': 2.5}

# %%
try :
    temp = 0
    for element in dict_key :
        element = diction[element]
        print(element)
        for i in range (0,len(element[0])):
            for micro_element in element:
                print(micro_element)
                temp+=micro_element[i]
                print(temp)
            temp = temp/len(element)
            print(temp)
            temp = 0
except:
    temp = 0
    for element in dict_key :
        element = diction[element]
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# [1, 2, 3]
# 1
# [4, 5, 6]
# 5
# [7, 8, 9]
# 12
# 4.0
# [1, 2, 3]
# 2
# [4, 5, 6]
# 7
# [7, 8, 9]
# 15
# 5.0
# [1, 2, 3]
# 3
# [4, 5, 6]
# 9
# [7, 8, 9]
# 18
# 6.0
# [1, 2, 3, 4, 5, 7, 8, 9, 10]
